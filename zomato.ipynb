# %% [markdown]
# <a href="https://colab.research.google.com/github/hanishad2006-hue/shopping/blob/main/zomato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
df=pd.read_csv("/content/Zomato-data-.csv")

# %%
display(df.tail())
# Out:
#                  name online_order book_table   rate  votes  \
# 143  Melting Melodies           No         No  3.3/5      0
# 144   New Indraprasta           No         No  3.3/5      0
# 145      Anna Kuteera          Yes         No  4.0/5    771
# 146            Darbar           No         No  3.0/5     98
# 147     Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 143                          100          Dining
# 144                          150          Dining
# 145                          450          Dining
# 146                          800          Dining
# 147                          200          Dining

# %%
display(df.head())
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_cost(for two people)', 'listed_in(type)'],
#       dtype='object')

# %%
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df.shape
# Out:
# (148, 7)

# %%
df.info
# Out:
# <bound method DataFrame.info of                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
pip install matplotlib

# %%
pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x='online_order',data=df,color='green')
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %%
sns.barplot(x='online_order',y='votes',data=df,color='blue')
# Out:
# <Axes: xlabel='online_order', ylabel='votes'>

# %%
sns.scatterplot(x='votes',y='rate',data=df,color='orange')
# Out:
# <Axes: xlabel='votes', ylabel='rate'>

# %%
df['rate']
# Out:
# 0      4.1/5
# 1      4.1/5
# 2      3.8/5
# 3      3.7/5
# 4      3.8/5
#        ...
# 143    3.3/5
# 144    3.3/5
# 145    4.0/5
# 146    3.0/5
# 147    3.9/5
# Name: rate, Length: 148, dtype: object

# %%
df[['rate','votes']]
# Out:
#       rate  votes
# 0    4.1/5    775
# 1    4.1/5    787
# 2    3.8/5    918
# 3    3.7/5     88
# 4    3.8/5    166
# ..     ...    ...
# 143  3.3/5      0
# 144  3.3/5      0
# 145  4.0/5    771
# 146  3.0/5     98
# 147  3.9/5     47
#
# [148 rows x 2 columns]

# %%
df_cleaned = df.copy()
df_cleaned['rate'] = df_cleaned['rate'].str.replace('/5', '', regex=False)
df_cleaned['rate'] = pd.to_numeric(df_cleaned['rate'], errors='coerce')
df_cleaned[['rate','votes']].corr()
# Out:
#            rate     votes
# rate   1.000000  0.489844
# votes  0.489844  1.000000

# %%
corr=df_cleaned[['rate','votes']].corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
pip install scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['listed_in(type)']=le.fit_transform(df['listed_in(type)'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['name']=le.fit_transform(df['name'])

# %%
df
# Out:
#      name  online_order  book_table   rate  votes  \
# 0      59             1           1  4.1/5    775
# 1     113             1           0  4.1/5    787
# 2     107             1           0  3.8/5    918
# 3       2             0           0  3.7/5     88
# 4      52             0           0  3.8/5    166
# ..    ...           ...         ...    ...    ...
# 143    83             0           0  3.3/5      0
# 144    89             0           0  3.3/5      0
# 145     4             1           0  4.0/5    771
# 146    35             0           0  3.0/5     98
# 147   139             1           0  3.9/5     47
#
#      approx_cost(for two people)  listed_in(type)
# 0                            800                0
# 1                            800                0
# 2                            800                0
# 3                            300                0
# 4                            600                0
# ..                           ...              ...
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
df['listed_in(type)']=oe.fit_transform(df[['listed_in(type)']])

# %%
df
# Out:
#      name  online_order  book_table   rate  votes  \
# 0      59             1           1  4.1/5    775
# 1     113             1           0  4.1/5    787
# 2     107             1           0  3.8/5    918
# 3       2             0           0  3.7/5     88
# 4      52             0           0  3.8/5    166
# ..    ...           ...         ...    ...    ...
# 143    83             0           0  3.3/5      0
# 144    89             0           0  3.3/5      0
# 145     4             1           0  4.0/5    771
# 146    35             0           0  3.0/5     98
# 147   139             1           0  3.9/5     47
#
#      approx_cost(for two people)  listed_in(type)
# 0                            800              0.0
# 1                            800              0.0
# 2                            800              0.0
# 3                            300              0.0
# 4                            600              0.0
# ..                           ...              ...
# ...

# %%
#df['votes']=df['votes'].fillna(df['votes'].mode()(0))
#df['votes']=df['votes'].fillna(df['votes'].mean()(0))

# %%
df.describe()
# Out:
#              name  online_order  book_table        votes  \
# count  148.000000    148.000000  148.000000   148.000000
# mean    71.993243      0.391892    0.054054   264.810811
# std     41.958920      0.489830    0.226892   653.676951
# min      0.000000      0.000000    0.000000     0.000000
# 25%     35.750000      0.000000    0.000000     6.750000
# 50%     72.500000      0.000000    0.000000    43.500000
# 75%    107.250000      1.000000    0.000000   221.750000
# max    144.000000      1.000000    1.000000  4884.000000
#
#        approx_cost(for two people)  listed_in(type)
# count                   148.000000       148.000000
# mean                    418.243243         1.804054
# std                     223.085098         0.602250
# min                     100.000000         0.000000
# 25%                     200.000000         2.000000
# 50%                     400.000000         2.000000
# 75%                     600.000000         2.000000
# ...

# %%
#df['listed_in(type)']=df['listed_in(type)'].fillna(df['listed_in(type)'].mode()(0))

# %%
df.describe()
# Out:
#              name  online_order  book_table        votes  \
# count  148.000000    148.000000  148.000000   148.000000
# mean    71.993243      0.391892    0.054054   264.810811
# std     41.958920      0.489830    0.226892   653.676951
# min      0.000000      0.000000    0.000000     0.000000
# 25%     35.750000      0.000000    0.000000     6.750000
# 50%     72.500000      0.000000    0.000000    43.500000
# 75%    107.250000      1.000000    0.000000   221.750000
# max    144.000000      1.000000    1.000000  4884.000000
#
#        approx_cost(for two people)  listed_in(type)
# count                   148.000000       148.000000
# mean                    418.243243         1.804054
# std                     223.085098         0.602250
# min                     100.000000         0.000000
# 25%                     200.000000         2.000000
# 50%                     400.000000         2.000000
# 75%                     600.000000         2.000000
# ...
